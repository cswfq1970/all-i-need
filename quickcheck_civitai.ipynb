# %% [markdown]
# <a href="https://colab.research.google.com/github/wfq1971/all-i-need/blob/main/quickcheck_civitai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

def download_url(url, filename):
    if os.path.isfile(filename):
       return

    from shlex import quote
    s_url = quote(url)
    s_filename = quote(filename)
    # !gdown {s_url} -O {s_filename}

def install_basemodel():
  if MODEL_TO_DOWNLOAD=='Anythingv3':
    download_url("https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp32-pruned.safetensors","/usr/fuck/models/Stable-diffusion/Anything-V3.0.safetensors")
    download_url("https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt","/usr/fuck/models/VAE/Anything-V3.0.vae.pt");

  if MODEL_TO_DOWNLOAD=='Anythingv3.1':
    download_url("https://huggingface.co/cag/anything-v3-1/resolve/main/anything-v3-1.safetensors", "/usr/fuck/models/anything-v3-1.safetensors")
    download_url("https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt","/usr/fuck/models/VAE/Anything-V3.0.vae.pt");

  if MODEL_TO_DOWNLOAD=='Anythingv4':
    download_url("https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.safetensors", "/usr/fuck/models/anything-v4.0-pruned.safetensors")
    download_url("https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt","/usr/fuck/models/VAE/anything-v4.0.vae.pt");

  if MODEL_TO_DOWNLOAD=='Anythingv4.5':
    download_url("https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned.safetensors", "/usr/fuck/models/anything-v4.5-pruned.safetensors")
    download_url("https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt","/usr/fuck/models/VAE/anything-v4.0.vae.pt");

  if MODEL_TO_DOWNLOAD=='Grapefruit':
    download_url("https://civitai.com/api/download/models/6360", "/usr/fuck/models/Stable-diffusion/grapefruitHentaiModel.safetensors")
  if MODEL_TO_DOWNLOAD=='chilloutmix':
    download_url("https://civitai.com/api/download/models/11745", "/usr/fuck/models/Stable-diffusion/chilloutmix_NiPrunedFp32Fix.safetensors")

  if MODEL_TO_DOWNLOAD=='AbyssOrangeMix2':
    download_url('https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors',"/usr/fuck/models/Stable-diffusion/AbyssOrangeMix2_hard.safetensors")
    download_url('https://huggingface.co/WarriorMama777/OrangeMixs/blob/main/VAEs/orangemix.vae.pt',"/usr/fuck/models/VAE/orangemix.vae.pt")

  if MODEL_TO_DOWNLOAD=='AbyssOrangeMix3':
    download_url('https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3.safetensors',"/usr/fuck/models/Stable-diffusion/AOM3.safetensors")
    download_url('https://huggingface.co/WarriorMama777/OrangeMixs/blob/main/VAEs/orangemix.vae.pt',"/usr/fuck/models/VAE/orangemix.vae.pt")

  if MODEL_TO_DOWNLOAD=='7th_Layer':
    download_url("https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_layer/Abyss_7th_layer.ckpt", "/usr/fuck/models/Abyss_7th_layer.ckpt")
    download_url("https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt","/usr/fuck/models/VAE/WD-vae.vae.pt");

  if MODEL_TO_DOWNLOAD=='7th_anime_v3':
    download_url("https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_A.safetensors", "/usr/fuck/models/7th_anime_v3_A.safetensors")
    download_url("https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt","/usr/fuck/models/VAE/WD-vae.vae.pt");

  if MODEL_TO_DOWNLOAD=='UmiAIMythologyAndBabes':
    download_url("https://civitai.com/api/download/models/15617", "/usr/fuck/models/umiAIMythologyAndBabes_macrossAnimeUltimate1.safetensors")
    download_url("https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt","/usr/fuck/models/VAE/vae-ft-mse-840000-ema-pruned.ckpt");


def my_cat(path):
  if not os.path.exists(path):
      return ""

  f = open(path, 'r', encoding="utf-8")
  txt = f.read().strip("\r\n")
  f.close()
  return txt

def install_webui():
  webui_type = my_cat("/content/webui_type")
  if webui_type != "":
    if webui_type == WEBUI_VERSION:
      return
    else:
      print(f"re-install webui: {WEBUI_VERSION}  oldver: {webui_type}");
      # !rm "/usr/fuck" -rf

  # %cd /content/
  if WEBUI_VERSION=="wpf 2.0":
    # !git clone -b v2.0 https://github.com/wfq1971/maybe-colab /usr/fuck
    # !gdown https://pastebin.com/raw/pKFWUfLM -O /usr/fuck/modules/ui.py

  elif WEBUI_VERSION=="wpf latest":
    # !git clone https://github.com/wfq1971/maybe-colab /usr/fuck
  else:
    # !git clone https://github.com/wfq1971/maybe-colab /usr/fuck

  # !gdown https://pastebin.com/raw/fmN0i5Sd -O /usr/fuck/ui-config.json
  # !gdown https://pastebin.com/raw/amVtB1NW -O /usr/fuck/config.json
  # !echo $WEBUI_VERSION > /content/webui_type


def install_etc():
  if os.path.isfile('/usr/fuck/embeddings/bad_prompt.pt'):
    return;

  #  !pip install -q --pre xformers triton fastapi
  # !apt -y install -qq aria2
  # !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
  # !pip install -q xformers==0.0.16 triton==2.0.0 -U

  # %cd /usr/fuck/extensions

  #setup lora dir
  if not os.path.exists('/usr/fuck/extensions/zhijie-wanglu/models/lora'):
    # !mkdir -p /usr/fuck/models/Lora
    # !mkdir -p /usr/fuck/extensions/zhijie-wanglu/models
    # !ln -s /usr/fuck/models/Lora /usr/fuck/extensions/zhijie-wanglu/models/lora

  if not os.path.exists('/usr/fuck/models/VAE'):
    # !mkdir -p /usr/fuck/models/VAE

  #badprompt & badartist
  download_url("https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt", "/usr/fuck/embeddings/bad_prompt.pt")
  download_url("https://huggingface.co/NiXXerHATTER59/bad-artist/resolve/main/bad-artist.pt", "/usr/fuck/embeddings/bad_artist.pt")
  download_url("https://www.dropbox.com/s/fzubirdvu3s5kup/bad_hands.pt?dl=1", "/usr/fuck/embeddings/bad_hands.pt")



def install_controlnet():
  if not USE_CONTROLNET:
    if os.path.exists('/usr/fuck/extensions/kongzhi-wanglu'):
      # !rm /usr/fuck/extensions/kongzhi-wanglu -rf
    return
  if os.path.exists('/usr/fuck/extensions/kongzhiwanglu'):
    return

  # !pip install opencv-python prettytable virtualenv omegaconf svglib
  # !git clone https://github.com/wfq1971/colab-kongzhiwangluo /usr/fuck/extensions/kongzhi-wanglu

  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_canny-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_depth-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_hed-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_mlsd-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_openpose-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_normal-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_scribble-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/control_seg-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_keypose-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/t2iadapter_keypose-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_seg-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/t2iadapter_seg-fp16.safetensors")
  download_url("https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/t2iadapter_sketch-fp16.safetensors","/usr/fuck/extensions/kongzhi-wanglu/models/t2iadapter_sketch-fp16.safetensors")

def launch():
  # %cd /usr/fuck/
  # !python launch.py --share --xformers --enable-insecure-extension-access --gradio-queue

MODEL_TO_DOWNLOAD="Anythingv3.1" #@param [ "Anythingv3.1", "Anythingv3", "Anythingv4", "Anythingv4.5", "Grapefruit", "chilloutmix", "AbyssOrangeMix2", "AbyssOrangeMix3", "7th_Layer", "7th_anime_v3", "UmiAIMythologyAndBabes"]
WEBUI_VERSION = "original cswpf repo" #@param ["wpf 2.0", "wpf latest", "original cswpf repo"]
USE_CONTROLNET = False #@param {type:"boolean"}

import subprocess
cek = subprocess.getoutput('nvidia-smi')
if not 'T4' in cek:
  print("[1;32m-----Your colab session is over. Use other google account or wait 12-24 hours-----")
  print("-----Sesi colab elu udah habis bro. Saran gw tunggu 12-24 jam atau bikin/pake akun google lain-----")
  raise KeyboardInterrupt

print('[1;32mInstalling...')
print('This process takes a few minutes')
print('[0m')

install_webui()
install_etc()
install_basemodel()
install_controlnet()
launch()

# %%
# !bash -c 'for repo in yfszzx/stable-diffusion-webui-images-browser DominikDoom/a1111-sd-webui-tagcomplete KohakuBlueleaf/LoCon butaixianran/Stable-Diffusion-Webui-Civitai-Helper; do if [ ! -d "$repo" ]; then git clone "https://github.com/$repo" && true; fi; done'

# %% [markdown]
# **This is a code to easily check LoRA and TextualInversion of CivitAI**
#
# The following are optional.<br>
# In MODEL_TO_DOWNLOAD, specify the model to be used for confirmation.<br>
# For WEBUI_VERSION, specify the version of WebUI.<br>
# Check USE_CONTROLNET to use controlnet as well.<br>
# Donation: <a href="https://www.patreon.com/a7743">https://www.patreon.com/a7743</a><br>
